# %% [markdown]
# ## 딥러닝에서 확률론이 필요한 이유?
# - 딥러닝은 확률론 기반의 기계학습 이론에 바탕을 두고 있음
# - 기계학습에서 사용되는 손실함수들은 데이터 공간을 통계적으로 해석해서 유도
#     - **회귀 분석**에서 손실함수로 사용되는 L2-노름은 **예측오차의 분산을 최소화**하는 방향으로 학습하도록 유도
#     - **분류 문제**에서 사용되는 교차엔트로피는 **모델 예측의 불확실성을 최소화**하는 방향으로 학습하도록 유도

# %% [markdown]
# 기호
# - 데이터 공간: $XxY$
# - 데이터 공간에서 데이터를 추출하는 분포: $D$
# - 데이터: $(x,y)$ ~ $D$

# %% [markdown]
# ## 이산확률변수 vs 연속확률변수
# - 확률변수는 확률분포 $D$에 따라 이산형과 연속형으로 구분
# - 이산형 확률변수는 확률변수가 가질 수 있는 모든 경우의 수를 고려하여 **확률을 더해서** 모델링
#     - $P(X=x)$: 확률변수가 x값을 가질 확률
# - 연속형 확률변수는 데이터 공간에 정의된 확률변수의 밀도 위에서 **적분을 통해** 모델링
#     - $\int_A P(x)\,\mathrm{d}x$

# %% [markdown]
# - 결합분포 $P(x,y)$: 주어진 데이터에 따라 $D$를 모델링
# - 주변확률분포 $P(x)$: y에 대한 정보는 주지 않음
# - 조건부확률분포 $P(x|y)$: 입력 x와 출력 y 사이의 관계를 모델링

# %% [markdown]
# ## 조건부확률과 기계학습
# - 조건부확률 $P(y|x)$: 입력 x에 대해 정답이 y일 확률
# - 분류 문제에서 softmax(Wϕ+b)는 x로부터 추출된 특징패턴 ϕ과 가중치행렬 W를 통해 조건부확률 $P(y|x)$ 계산
# - 회귀 문제의 경우 조건부기대값 $E[y|x]$ 추정
# - 다층신경망을 사용하여 특징페턴 ϕ 추출

# %% [markdown]
# ## 기대값 E(X)
# ![image.png](attachment:image.png)
# - 데이터를 대표하는 통계량 (평균)
# - 통계적 범함수 계산 가능
# - 기대값을 이용해 **분산, 첨도, 공분산** 등 통계량 계산 가능
#     - 분산: $V(X)=E[X^2]-E[X]^2$

# %% [markdown]
# # 몬테카를로 샘플링
# - 대부분의 기계학습 문제들은 확률분포를 명시적으로 모름
# - **확률분포를 모를 때** 데이터를 이용하여 기대값을 계산하려면 **몬테카를로 샘플링 방법 사용**
# - 독립 추출이 보장된다면 **대수의 법칙에 의해 수렴성을 보장**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 예제: 함수 $f(x)=e^{-x^2}$의 [-1,1] 상에서의 적분값
#     ![image.png](attachment:image.png)

# %%
#코드 풀이
import numpy as np

def mc_int(fun, low, high, sample_size=100, repeat=10):
    int_len = np.abs(high-low) # 적분 범위 
    stat = [] 
    for _ in range(repeat):
        # 균등분포로 sample_size만큼 [low, high] 구간의 x값을 추출한다.
        x = np.random.uniform(low=low, high=high, size=sample_size) 
        fun_x = fun(x)
        int_val = int_len * np.mean(fun_x)
        stat.append(int_val)

    # 구해진 통계량(넓이)를 평균내주면 실제 값과 거의 근사한다.
    return np.mean(stat), np.std(stat) # 적분값과 오차


def f_x(x): #들어갈 함수식
    return np.exp(-x**2)

#[-1,1] 구간의 적분값
print(mc_int(f_x, -1, 1, 10000, 100))
# Out:
# (1.493708832976965, 0.003877116400880967)

# %% [markdown]
# ## Further Question
# Q. 몬테카를로 방법을 활용하여 원주율에 대한 근삿값을 어떻게 구할 수 있을까요?
# > 정사각형에 한변의 길이가 지름이 되도록 원을 넣고 샘플링해서 뽑히는 비율을 통해서 구해볼 수 있다.
#
# - 우선 원을 1/4 등분하기
# ![image.png](attachment:image.png)

# %%
import random
n=1000000
count=0 #점의 개수
circle=0
while True:
    for i in range(n):
        x=random.random() # 0~1 사이의 float 값
        y=random.random()
        count+=1
        if x**2+y**2<1: # 단위원 안에 있으면
            circle+=1
    print(f"점의 개수:{count}, 원주율의 근사값:{(circle/count)*4}") #1/4 등분한 원주 다시 되돌리기
# Out:
# 점의 개수:1000000, 원주율의 근사값:3.141752
# 점의 개수:2000000, 원주율의 근사값:3.142736
# 점의 개수:3000000, 원주율의 근사값:3.1420613333333334
# 점의 개수:4000000, 원주율의 근사값:3.141855
# 점의 개수:5000000, 원주율의 근사값:3.1415624
# 점의 개수:6000000, 원주율의 근사값:3.1414853333333332
# 점의 개수:7000000, 원주율의 근사값:3.141705714285714
# 점의 개수:8000000, 원주율의 근사값:3.141642
# 점의 개수:9000000, 원주율의 근사값:3.141725777777778
# 점의 개수:10000000, 원주율의 근사값:3.1420892
# 점의 개수:11000000, 원주율의 근사값:3.141981090909091
# 점의 개수:12000000, 원주율의 근사값:3.141876
# 점의 개수:13000000, 원주율의 근사값:3.1416984615384616
# 점의 개수:14000000, 원주율의 근사값:3.141712857142857
# 점의 개수:15000000, 원주율의 근사값:3.1418570666666668
# 점의 개수:16000000, 원주율의 근사값:3.14193975
# 점의 개수:17000000, 원주율의 근사값:3.141899294117647
# 점의 개수:18000000, 원주율의 근사값:3.1419882222222224
# 점의 개수:19000000, 원주율의 근사값:3.142116842105263
# 점의 개수:20000000, 원주율의 근사값:3.1420926
# 점의 개수:21000000, 원주율의 근사값:3.1421834285714287
# 점의 개수:22000000, 원주율의 근사값:3.1422981818181817
# 점의 개수:23000000, 원주율의 근사값:3.1422937391304346
# 점의 개수:24000000, 원주율의 근사값:3.1424773333333333
# 점의 개수:25000000, 원주율의 근사값:3.14257248
# 점의 개수:26000000, 원주율의 근사값:3.1425124615384616
# 점의 개수:27000000, 원주율의 근사값:3.1425752592592593
# 점의 개수:28000000, 원주율의 근사값:3.1424904285714286
# 점의 개수:29000000, 원주율의 근사값:3.1423715862068966
# 점의 개수:30000000, 원주율의 근사값:3.1423810666666667
# 점의 개수:31000000, 원주율의 근사값:3.142342322580645
# 점의 개수:32000000, 원주율의 근사값:3.142324125
# 점의 개수:33000000, 원주율의 근사값:3.1423136969696968
# 점의 개수:34000000, 원주율의 근사값:3.142266705882353
# 점의 개수:35000000, 원주율의 근사값:3.142231314285714
# 점의 개수:36000000, 원주율의 근사값:3.142232888888889
# 점의 개수:37000000, 원주율의 근사값:3.1421967567567566
# 점의 개수:38000000, 원주율의 근사값:3.1421464210526318
# 점의 개수:39000000, 원주율의 근사값:3.142150564102564
# 점의 개수:40000000, 원주율의 근사값:3.1421299
# 점의 개수:41000000, 원주율의 근사값:3.1421316097560976
# 점의 개수:42000000, 원주율의 근사값:3.1421747619047617
# 점의 개수:43000000, 원주율의 근사값:3.1421928372093024
# 점의 개수:44000000, 원주율의 근사값:3.142211272727273
# 점의 개수:45000000, 원주율의 근사값:3.1421825777777777
# 점의 개수:46000000, 원주율의 근사값:3.1421671304347827
# 점의 개수:47000000, 원주율의 근사값:3.142150723404255
# 점의 개수:48000000, 원주율의 근사값:3.142135666666667
# 점의 개수:49000000, 원주율의 근사값:3.142144
# 점의 개수:50000000, 원주율의 근사값:3.14212928
# 점의 개수:51000000, 원주율의 근사값:3.1421139607843136
# 점의 개수:52000000, 원주율의 근사값:3.142080230769231
# 점의 개수:53000000, 원주율의 근사값:3.142014037735849
# 점의 개수:54000000, 원주율의 근사값:3.142025925925926
# 점의 개수:55000000, 원주율의 근사값:3.1419852363636362
# 점의 개수:56000000, 원주율의 근사값:3.1419760714285716
# 점의 개수:57000000, 원주율의 근사값:3.141952842105263
# 점의 개수:58000000, 원주율의 근사값:3.1419915862068963
# 점의 개수:59000000, 원주율의 근사값:3.1420137627118643
# 점의 개수:60000000, 원주율의 근사값:3.1419975333333334
# 점의 개수:61000000, 원주율의 근사값:3.1419940983606556
# 점의 개수:62000000, 원주율의 근사값:3.1419453548387097
# 점의 개수:63000000, 원주율의 근사값:3.141917396825397
# 점의 개수:64000000, 원주율의 근사값:3.1419510625
# 점의 개수:65000000, 원주율의 근사값:3.141904307692308
# 점의 개수:66000000, 원주율의 근사값:3.1419098181818184
# 점의 개수:67000000, 원주율의 근사값:3.141898089552239
# 점의 개수:68000000, 원주율의 근사값:3.1418409411764707
# 점의 개수:69000000, 원주율의 근사값:3.1417897971014495
# 점의 개수:70000000, 원주율의 근사값:3.141790914285714
# 점의 개수:71000000, 원주율의 근사값:3.141778704225352
# 점의 개수:72000000, 원주율의 근사값:3.141756722222222
# 점의 개수:73000000, 원주율의 근사값:3.1417781369863014
# 점의 개수:74000000, 원주율의 근사값:3.141806
# 점의 개수:75000000, 원주율의 근사값:3.14183408
# 점의 개수:76000000, 원주율의 근사값:3.1418395263157897
# 점의 개수:77000000, 원주율의 근사값:3.141856051948052
# 점의 개수:78000000, 원주율의 근사값:3.1418824102564105
# 점의 개수:79000000, 원주율의 근사값:3.1419267341772152
# 점의 개수:80000000, 원주율의 근사값:3.14194635
# 점의 개수:81000000, 원주율의 근사값:3.1419136296296295
# 점의 개수:82000000, 원주율의 근사값:3.1419029268292684
# 점의 개수:83000000, 원주율의 근사값:3.1419386987951805
# 점의 개수:84000000, 원주율의 근사값:3.141936952380952
# 점의 개수:85000000, 원주율의 근사값:3.1419370823529413
# 점의 개수:86000000, 원주율의 근사값:3.141923348837209
# 점의 개수:87000000, 원주율의 근사값:3.141922712643678
# 점의 개수:88000000, 원주율의 근사값:3.1419165454545452
# 점의 개수:89000000, 원주율의 근사값:3.1418917303370786
# 점의 개수:90000000, 원주율의 근사값:3.141926088888889
# 점의 개수:91000000, 원주율의 근사값:3.1419106813186812
# 점의 개수:92000000, 원주율의 근사값:3.141880347826087
# 점의 개수:93000000, 원주율의 근사값:3.141893806451613
# 점의 개수:94000000, 원주율의 근사값:3.1418590212765958
# 점의 개수:95000000, 원주율의 근사값:3.1418608842105265
# 점의 개수:96000000, 원주율의 근사값:3.141868125
# 점의 개수:97000000, 원주율의 근사값:3.141863917525773
# 점의 개수:98000000, 원주율의 근사값:3.141850448979592
# 점의 개수:99000000, 원주율의 근사값:3.1418622626262627
# 점의 개수:100000000, 원주율의 근사값:3.14189372
# 점의 개수:101000000, 원주율의 근사값:3.141879168316832
# 점의 개수:102000000, 원주율의 근사값:3.141872745098039
# 점의 개수:103000000, 원주율의 근사값:3.1418874951456313
# 점의 개수:104000000, 원주율의 근사값:3.141880846153846
# 점의 개수:105000000, 원주율의 근사값:3.1418537523809524
# 점의 개수:106000000, 원주율의 근사값:3.1418618490566037
# 점의 개수:107000000, 원주율의 근사값:3.141850018691589
# 점의 개수:108000000, 원주율의 근사값:3.1418334074074075
# 점의 개수:109000000, 원주율의 근사값:3.1418388990825687
# 점의 개수:110000000, 원주율의 근사값:3.1418253454545453
# 점의 개수:111000000, 원주율의 근사값:3.14183618018018
# 점의 개수:112000000, 원주율의 근사값:3.141851714285714
# 점의 개수:113000000, 원주율의 근사값:3.141845592920354
# 점의 개수:114000000, 원주율의 근사값:3.1418511228070174
# 점의 개수:115000000, 원주율의 근사값:3.141841460869565
# 점의 개수:116000000, 원주율의 근사값:3.1418408620689657
# 점의 개수:117000000, 원주율의 근사값:3.14183894017094
# 점의 개수:118000000, 원주율의 근사값:3.1418558305084745
# 점의 개수:119000000, 원주율의 근사값:3.1418496470588235
# 점의 개수:120000000, 원주율의 근사값:3.1418554333333333
# 점의 개수:121000000, 원주율의 근사값:3.141867074380165
# 점의 개수:122000000, 원주율의 근사값:3.141841344262295
# 점의 개수:123000000, 원주율의 근사값:3.1418704715447157
# 점의 개수:124000000, 원주율의 근사값:3.141863548387097
# 점의 개수:125000000, 원주율의 근사값:3.14184816
# 점의 개수:126000000, 원주율의 근사값:3.14186146031746
# 점의 개수:127000000, 원주율의 근사값:3.1418734173228344
# 점의 개수:128000000, 원주율의 근사값:3.14185996875
# 점의 개수:129000000, 원주율의 근사값:3.1418742635658914
# 점의 개수:130000000, 원주율의 근사값:3.1418757538461537
# 점의 개수:131000000, 원주율의 근사값:3.1418613129770994
# 점의 개수:132000000, 원주율의 근사값:3.1418755454545453
# 점의 개수:133000000, 원주율의 근사값:3.1418795488721805
# 점의 개수:134000000, 원주율의 근사값:3.1418842388059702
# 점의 개수:135000000, 원주율의 근사값:3.141897748148148
# 점의 개수:136000000, 원주율의 근사값:3.1418955588235296
# 점의 개수:137000000, 원주율의 근사값:3.1418976350364964
# 점의 개수:138000000, 원주율의 근사값:3.1418764347826085
# 점의 개수:139000000, 원주율의 근사값:3.1418669352517985
# 점의 개수:140000000, 원주율의 근사값:3.141848942857143
# 점의 개수:141000000, 원주율의 근사값:3.1418656737588653
# 점의 개수:142000000, 원주율의 근사값:3.141864985915493
# 점의 개수:143000000, 원주율의 근사값:3.141879244755245
# 점의 개수:144000000, 원주율의 근사값:3.1418856388888887
# 점의 개수:145000000, 원주율의 근사값:3.1418692137931035
# 점의 개수:146000000, 원주율의 근사값:3.1418592602739728
# 점의 개수:147000000, 원주율의 근사값:3.141845904761905
# 점의 개수:148000000, 원주율의 근사값:3.1418377297297297
# 점의 개수:149000000, 원주율의 근사값:3.1418271677852347
# 점의 개수:150000000, 원주율의 근사값:3.14184248
# 점의 개수:151000000, 원주율의 근사값:3.1418419337748342
# 점의 개수:152000000, 원주율의 근사값:3.141840157894737
# 점의 개수:153000000, 원주율의 근사값:3.141857751633987
# 점의 개수:154000000, 원주율의 근사값:3.141832233766234
# 점의 개수:155000000, 원주율의 근사값:3.1418309161290323
# 점의 개수:156000000, 원주율의 근사값:3.1418261025641026
# 점의 개수:157000000, 원주율의 근사값:3.141828356687898
# 점의 개수:158000000, 원주율의 근사값:3.1418296962025316
# 점의 개수:159000000, 원주율의 근사값:3.1418334842767295
# 점의 개수:160000000, 원주율의 근사값:3.14183205
# 점의 개수:161000000, 원주율의 근사값:3.1418243229813663
# 점의 개수:162000000, 원주율의 근사값:3.141828987654321
# 점의 개수:163000000, 원주율의 근사값:3.14182090797546
# 점의 개수:164000000, 원주율의 근사값:3.1418154146341464
# 점의 개수:165000000, 원주율의 근사값:3.1418267636363635
# 점의 개수:166000000, 원주율의 근사값:3.141825277108434
# 점의 개수:167000000, 원주율의 근사값:3.1418155449101794
# 점의 개수:168000000, 원주율의 근사값:3.1418133333333333
# 점의 개수:169000000, 원주율의 근사값:3.1418118579881655
# 점의 개수:170000000, 원주율의 근사값:3.1418032705882353
# 점의 개수:171000000, 원주율의 근사값:3.141788
# 점의 개수:172000000, 원주율의 근사값:3.141784511627907
# 점의 개수:173000000, 원주율의 근사값:3.1417862196531794
# 점의 개수:174000000, 원주율의 근사값:3.141775172413793
# 점의 개수:175000000, 원주율의 근사값:3.141780502857143
# 점의 개수:176000000, 원주율의 근사값:3.14178
# 점의 개수:177000000, 원주율의 근사값:3.14178011299435
# 점의 개수:178000000, 원주율의 근사값:3.141768831460674
# 점의 개수:179000000, 원주율의 근사값:3.1417762681564247
# 점의 개수:180000000, 원주율의 근사값:3.141773911111111
# 점의 개수:181000000, 원주율의 근사값:3.14177217679558
# 점의 개수:182000000, 원주율의 근사값:3.141763230769231
# 점의 개수:183000000, 원주율의 근사값:3.141776087431694
# 점의 개수:184000000, 원주율의 근사값:3.141761130434783
# 점의 개수:185000000, 원주율의 근사값:3.141746356756757
# 점의 개수:186000000, 원주율의 근사값:3.1417450322580645
# 점의 개수:187000000, 원주율의 근사값:3.141742631016043
# 점의 개수:188000000, 원주율의 근사값:3.1417321489361703
# 점의 개수:189000000, 원주율의 근사값:3.1417281058201056
# 점의 개수:190000000, 원주율의 근사값:3.1417086947368422
# 점의 개수:191000000, 원주율의 근사값:3.1417196858638743
# 점의 개수:192000000, 원주율의 근사값:3.1417277291666665
# 점의 개수:193000000, 원주율의 근사값:3.141732994818653
# 점의 개수:194000000, 원주율의 근사값:3.141735525773196
# 점의 개수:195000000, 원주율의 근사값:3.141727835897436
# 점의 개수:196000000, 원주율의 근사값:3.1417188979591835
# 점의 개수:197000000, 원주율의 근사값:3.1417158172588833
# 점의 개수:198000000, 원주율의 근사값:3.141719292929293
# 점의 개수:199000000, 원주율의 근사값:3.1417053467336684
# 점의 개수:200000000, 원주율의 근사값:3.14170992
# 점의 개수:201000000, 원주율의 근사값:3.1417197611940297
# 점의 개수:202000000, 원주율의 근사값:3.141714316831683
# 점의 개수:203000000, 원주율의 근사값:3.1417166502463054
# 점의 개수:204000000, 원주율의 근사값:3.141722862745098
# 점의 개수:205000000, 원주율의 근사값:3.1417168
# 점의 개수:206000000, 원주율의 근사값:3.141706932038835
# 점의 개수:207000000, 원주율의 근사값:3.1417132946859905
# 점의 개수:208000000, 원주율의 근사값:3.1417247884615382
# 점의 개수:209000000, 원주율의 근사값:3.141713052631579
# 점의 개수:210000000, 원주율의 근사값:3.141714266666667
# 점의 개수:211000000, 원주율의 근사값:3.141731829383886
# 점의 개수:212000000, 원주율의 근사값:3.141738603773585
# 점의 개수:213000000, 원주율의 근사값:3.1417450516431926
# 점의 개수:214000000, 원주율의 근사값:3.1417427289719626
# 점의 개수:215000000, 원주율의 근사값:3.1417223627906976
# 점의 개수:216000000, 원주율의 근사값:3.141734425925926
# 점의 개수:217000000, 원주율의 근사값:3.1417430230414745
# 점의 개수:218000000, 원주율의 근사값:3.1417431559633027
# 점의 개수:219000000, 원주율의 근사값:3.141736803652968
# 점의 개수:220000000, 원주율의 근사값:3.141737327272727
# 점의 개수:221000000, 원주율의 근사값:3.1417434570135745
# 점의 개수:222000000, 원주율의 근사값:3.141749891891892
# 점의 개수:223000000, 원주율의 근사값:3.1417547085201796
# 점의 개수:224000000, 원주율의 근사값:3.1417374642857143
# 점의 개수:225000000, 원주율의 근사값:3.141726542222222
# 점의 개수:226000000, 원주율의 근사값:3.1417242123893807
# 점의 개수:227000000, 원주율의 근사값:3.141728511013216
# 점의 개수:228000000, 원주율의 근사값:3.141723456140351
# 점의 개수:229000000, 원주율의 근사값:3.141714934497817
# 점의 개수:230000000, 원주율의 근사값:3.1417152347826085
# 점의 개수:231000000, 원주율의 근사값:3.1417109956709957
# 점의 개수:232000000, 원주율의 근사값:3.1417209827586206
# 점의 개수:233000000, 원주율의 근사값:3.1417176309012875
# 점의 개수:234000000, 원주율의 근사값:3.141713811965812
# 점의 개수:235000000, 원주율의 근사값:3.1417170723404255
# 점의 개수:236000000, 원주율의 근사값:3.141717525423729
# 점의 개수:237000000, 원주율의 근사값:3.141723864978903
# 점의 개수:238000000, 원주율의 근사값:3.1417232100840335
# 점의 개수:239000000, 원주율의 근사값:3.141733221757322
# 점의 개수:240000000, 원주율의 근사값:3.1417373833333335
# 점의 개수:241000000, 원주율의 근사값:3.141734622406639
# 점의 개수:242000000, 원주율의 근사값:3.1417303801652894
# 점의 개수:243000000, 원주율의 근사값:3.1417337119341564
# 점의 개수:244000000, 원주율의 근사값:3.1417516721311474
# 점의 개수:245000000, 원주율의 근사값:3.141751379591837
# 점의 개수:246000000, 원주율의 근사값:3.1417543739837397
# 점의 개수:247000000, 원주율의 근사값:3.1417457813765184
# 점의 개수:248000000, 원주율의 근사값:3.141742241935484
# 점의 개수:249000000, 원주율의 근사값:3.141748578313253
# 점의 개수:250000000, 원주율의 근사값:3.141751296
# 점의 개수:251000000, 원주율의 근사값:3.141753784860558
# 점의 개수:252000000, 원주율의 근사값:3.141756238095238
# 점의 개수:253000000, 원주율의 근사값:3.1417649644268772
# 점의 개수:254000000, 원주율의 근사값:3.1417642677165354
# 점의 개수:255000000, 원주율의 근사값:3.1417754980392156
# 점의 개수:256000000, 원주율의 근사값:3.14177634375
# 점의 개수:257000000, 원주율의 근사값:3.141780171206226
# 점의 개수:258000000, 원주율의 근사값:3.1417827596899226
# 점의 개수:259000000, 원주율의 근사값:3.141776216216216
# 점의 개수:260000000, 원주율의 근사값:3.1417717076923077
# 점의 개수:261000000, 원주율의 근사값:3.14178153256705
# 점의 개수:262000000, 원주율의 근사값:3.1417786564885497
# 점의 개수:263000000, 원주율의 근사값:3.1417733536121673
# 점의 개수:264000000, 원주율의 근사값:3.1417714696969696
# 점의 개수:265000000, 원주율의 근사값:3.141781449056604
# 점의 개수:266000000, 원주율의 근사값:3.1417801353383457
# 점의 개수:267000000, 원주율의 근사값:3.141782082397004
# 점의 개수:268000000, 원주율의 근사값:3.141782985074627
# 점의 개수:269000000, 원주율의 근사값:3.141781189591078
# 점의 개수:270000000, 원주율의 근사값:3.141775451851852
# 점의 개수:271000000, 원주율의 근사값:3.1417749077490775
# 점의 개수:272000000, 원주율의 근사값:3.1417679705882353
# 점의 개수:273000000, 원주율의 근사값:3.1417675311355313
# 점의 개수:274000000, 원주율의 근사값:3.141766
# 점의 개수:275000000, 원주율의 근사값:3.14177248
# 점의 개수:276000000, 원주율의 근사값:3.1417778985507248
# 점의 개수:277000000, 원주율의 근사값:3.1417792779783396
# 점의 개수:278000000, 원주율의 근사값:3.1417747050359712
# 점의 개수:279000000, 원주율의 근사값:3.141782394265233
# 점의 개수:280000000, 원주율의 근사값:3.1417864428571427
# 점의 개수:281000000, 원주율의 근사값:3.141777864768683
# 점의 개수:282000000, 원주율의 근사값:3.141773035460993
# 점의 개수:283000000, 원주율의 근사값:3.1417746431095406
# 점의 개수:284000000, 원주율의 근사값:3.141772295774648
# 점의 개수:285000000, 원주율의 근사값:3.14177550877193
# 점의 개수:286000000, 원주율의 근사값:3.14177806993007
# 점의 개수:287000000, 원주율의 근사값:3.141776975609756
# 점의 개수:288000000, 원주율의 근사값:3.141779027777778
# 점의 개수:289000000, 원주율의 근사값:3.1417858546712805
# 점의 개수:290000000, 원주율의 근사값:3.141786027586207
# 점의 개수:291000000, 원주율의 근사값:3.1417883573883163
# 점의 개수:292000000, 원주율의 근사값:3.141783109589041
# 점의 개수:293000000, 원주율의 근사값:3.1417856928327645
# 점의 개수:294000000, 원주율의 근사값:3.141782666666667
# 점의 개수:295000000, 원주율의 근사값:3.1417901016949155
# 점의 개수:296000000, 원주율의 근사값:3.141792
# 점의 개수:297000000, 원주율의 근사값:3.141785952861953
# 점의 개수:298000000, 원주율의 근사값:3.141789342281879
# 점의 개수:299000000, 원주율의 근사값:3.1417967224080265
# 점의 개수:300000000, 원주율의 근사값:3.1417881733333335
# 점의 개수:301000000, 원주율의 근사값:3.141790312292359
# 점의 개수:302000000, 원주율의 근사값:3.1417874834437085
# 점의 개수:303000000, 원주율의 근사값:3.141786059405941
# 점의 개수:304000000, 원주율의 근사값:3.1417779736842104
# 점의 개수:305000000, 원주율의 근사값:3.14177251147541
# 점의 개수:306000000, 원주율의 근사값:3.1417661960784313
# 점의 개수:307000000, 원주율의 근사값:3.141761693811075
# 점의 개수:308000000, 원주율의 근사값:3.1417647142857144
# 점의 개수:309000000, 원주율의 근사값:3.141771689320388
# 점의 개수:310000000, 원주율의 근사값:3.1417746064516128
# 점의 개수:311000000, 원주율의 근사값:3.141771729903537
# 점의 개수:312000000, 원주율의 근사값:3.141775076923077
# 점의 개수:313000000, 원주율의 근사값:3.141776498402556
# 점의 개수:314000000, 원주율의 근사값:3.141783617834395
# 점의 개수:315000000, 원주율의 근사값:3.141784292063492
# 점의 개수:316000000, 원주율의 근사값:3.1417935316455696
# 점의 개수:317000000, 원주율의 근사값:3.1417920378548896
# 점의 개수:318000000, 원주율의 근사값:3.1417900628930817
# 점의 개수:319000000, 원주율의 근사값:3.1417876614420064
# 점의 개수:320000000, 원주율의 근사값:3.14178945
# 점의 개수:321000000, 원주율의 근사값:3.14179246105919
# 점의 개수:322000000, 원주율의 근사값:3.1417972173913045
# 점의 개수:323000000, 원주율의 근사값:3.1417961114551085
# 점의 개수:324000000, 원주율의 근사값:3.141800197530864
# 점의 개수:325000000, 원주율의 근사값:3.1417949661538462
# 점의 개수:326000000, 원주율의 근사값:3.1417986503067485
# 점의 개수:327000000, 원주율의 근사값:3.141800721712538
# 점의 개수:328000000, 원주율의 근사값:3.1418127317073172
# 점의 개수:329000000, 원주율의 근사값:3.1418192340425533
# 점의 개수:330000000, 원주율의 근사값:3.1418251515151514
# 점의 개수:331000000, 원주율의 근사값:3.1418249546827797
# 점의 개수:332000000, 원주율의 근사값:3.1418206144578313
# 점의 개수:333000000, 원주율의 근사값:3.1418244324324323
# 점의 개수:334000000, 원주율의 근사값:3.141822083832335
# 점의 개수:335000000, 원주율의 근사값:3.1418230208955222
# 점의 개수:336000000, 원주율의 근사값:3.1418241428571427
# 점의 개수:337000000, 원주율의 근사값:3.1418263026706232
# 점의 개수:338000000, 원주율의 근사값:3.141821621301775
# 점의 개수:339000000, 원주율의 근사값:3.141814843657817
# 점의 개수:340000000, 원주율의 근사값:3.1418100823529413
# 점의 개수:341000000, 원주율의 근사값:3.1418012903225807
# 점의 개수:342000000, 원주율의 근사값:3.141803438596491
# 점의 개수:343000000, 원주율의 근사값:3.1418109271137027
# 점의 개수:344000000, 원주율의 근사값:3.1418155930232556
# 점의 개수:345000000, 원주율의 근사값:3.141810597101449
# 점의 개수:346000000, 원주율의 근사값:3.1418120462427748
# 점의 개수:347000000, 원주율의 근사값:3.141817706051873
# 점의 개수:348000000, 원주율의 근사값:3.141816620689655
# 점의 개수:349000000, 원주율의 근사값:3.1418204240687677
# 점의 개수:350000000, 원주율의 근사값:3.1418192
# 점의 개수:351000000, 원주율의 근사값:3.1418180626780625
# 점의 개수:352000000, 원주율의 근사값:3.1418142045454545
# 점의 개수:353000000, 원주율의 근사값:3.141813257790368
# 점의 개수:354000000, 원주율의 근사값:3.1418098418079095
# 점의 개수:355000000, 원주율의 근사값:3.141807414084507
# 점의 개수:356000000, 원주율의 근사값:3.1418086853932583
# 점의 개수:357000000, 원주율의 근사값:3.1418078655462183
# 점의 개수:358000000, 원주율의 근사값:3.1418161117318437
# 점의 개수:359000000, 원주율의 근사값:3.1418238551532034
# 점의 개수:360000000, 원주율의 근사값:3.1418205444444443
# 점의 개수:361000000, 원주율의 근사값:3.14182432132964
# 점의 개수:362000000, 원주율의 근사값:3.141824453038674
# 점의 개수:363000000, 원주율의 근사값:3.1418207272727274
# 점의 개수:364000000, 원주율의 근사값:3.141814945054945
# 점의 개수:365000000, 원주율의 근사값:3.1418202630136984
# 점의 개수:366000000, 원주율의 근사값:3.141820076502732
# 점의 개수:367000000, 원주율의 근사값:3.1418165776566758
# 점의 개수:368000000, 원주율의 근사값:3.141814032608696
# 점의 개수:369000000, 원주율의 근사값:3.141817452574526
# 점의 개수:370000000, 원주율의 근사값:3.141818897297297
# 점의 개수:371000000, 원주율의 근사값:3.1418167870619946
# 점의 개수:372000000, 원주율의 근사값:3.1418237849462365
# 점의 개수:373000000, 원주율의 근사값:3.1418191206434316
# 점의 개수:374000000, 원주율의 근사값:3.141826203208556
# 점의 개수:375000000, 원주율의 근사값:3.141830336
# 점의 개수:376000000, 원주율의 근사값:3.141835106382979
# 점의 개수:377000000, 원주율의 근사값:3.1418363925729444
# 점의 개수:378000000, 원주율의 근사값:3.1418307936507937
# 점의 개수:379000000, 원주율의 근사값:3.1418340897097625
# 점의 개수:380000000, 원주율의 근사값:3.1418302210526314
# 점의 개수:381000000, 원주율의 근사값:3.141830792650919
# 점의 개수:382000000, 원주율의 근사값:3.1418273717277487
# 점의 개수:383000000, 원주율의 근사값:3.1418298067885115
# 점의 개수:384000000, 원주율의 근사값:3.14183203125
# 점의 개수:385000000, 원주율의 근사값:3.1418329246753247
# 점의 개수:386000000, 원주율의 근사값:3.1418275336787564
# 점의 개수:387000000, 원주율의 근사값:3.141825354005168
# 점의 개수:388000000, 원주율의 근사값:3.141828443298969
# 점의 개수:389000000, 원주율의 근사값:3.1418251311053984
# 점의 개수:390000000, 원주율의 근사값:3.1418240923076923
# 점의 개수:391000000, 원주율의 근사값:3.141822547314578
# 점의 개수:392000000, 원주율의 근사값:3.141820214285714
# 점의 개수:393000000, 원주율의 근사값:3.1418209262086516
# 점의 개수:394000000, 원주율의 근사값:3.1418116751269034
# 점의 개수:395000000, 원주율의 근사값:3.1418055797468356
# 점의 개수:396000000, 원주율의 근사값:3.1418117171717173
# 점의 개수:397000000, 원주율의 근사값:3.1418219647355166
# 점의 개수:398000000, 원주율의 근사값:3.141821376884422
# 점의 개수:399000000, 원주율의 근사값:3.1418156390977443
# 점의 개수:400000000, 원주율의 근사값:3.14181208
# 점의 개수:401000000, 원주율의 근사값:3.141803710723192
# 점의 개수:402000000, 원주율의 근사값:3.1418043084577114
# 점의 개수:403000000, 원주율의 근사값:3.141807434243176
# 점의 개수:404000000, 원주율의 근사값:3.1418083168316833
# 점의 개수:405000000, 원주율의 근사값:3.141805540740741
# 점의 개수:406000000, 원주율의 근사값:3.141804512315271
# 점의 개수:407000000, 원주율의 근사값:3.1418082063882062
# 점의 개수:408000000, 원주율의 근사값:3.1418067843137254
# 점의 개수:409000000, 원주율의 근사값:3.1418049388753055
# 점의 개수:410000000, 원주율의 근사값:3.14180116097561
# 점의 개수:411000000, 원주율의 근사값:3.1418021703163017
# 점의 개수:412000000, 원주율의 근사값:3.141804087378641
# 점의 개수:413000000, 원주율의 근사값:3.1418033898305087
# 점의 개수:414000000, 원주율의 근사값:3.1417968309178743
# 점의 개수:415000000, 원주율의 근사값:3.141794592771084
# 점의 개수:416000000, 원주율의 근사값:3.141801403846154
# 점의 개수:417000000, 원주율의 근사값:3.141799568345324
# 점의 개수:418000000, 원주율의 근사값:3.1417941531100477
# 점의 개수:419000000, 원주율의 근사값:3.1417917326968974
# 점의 개수:420000000, 원주율의 근사값:3.1417984285714287
# 점의 개수:421000000, 원주율의 근사값:3.141798080760095
# 점의 개수:422000000, 원주율의 근사값:3.141799478672986
# 점의 개수:423000000, 원주율의 근사값:3.141796869976359
# 점의 개수:424000000, 원주율의 근사값:3.141797650943396
# 점의 개수:425000000, 원주율의 근사값:3.14179328
# 점의 개수:426000000, 원주율의 근사값:3.141792525821596
# 점의 개수:427000000, 원주율의 근사값:3.1417879531615927
# 점의 개수:428000000, 원주율의 근사값:3.1417818878504673
# 점의 개수:429000000, 원주율의 근사값:3.1417874778554777
# 점의 개수:430000000, 원주율의 근사값:3.1417901953488374
# 점의 개수:431000000, 원주율의 근사값:3.141790385150812
# 점의 개수:432000000, 원주율의 근사값:3.141788666666667
# 점의 개수:433000000, 원주율의 근사값:3.141786688221709
# 점의 개수:434000000, 원주율의 근사값:3.141791520737327
# 점의 개수:435000000, 원주율의 근사값:3.1417951540229887
# 점의 개수:436000000, 원주율의 근사값:3.1417920733944955
# 점의 개수:437000000, 원주율의 근사값:3.141791917620137
# 점의 개수:438000000, 원주율의 근사값:3.1417952785388126
# 점의 개수:439000000, 원주율의 근사값:3.141795653758542
# 점의 개수:440000000, 원주율의 근사값:3.141794472727273
# 점의 개수:441000000, 원주율의 근사값:3.1418019138321998
# 점의 개수:442000000, 원주율의 근사값:3.141799366515837
# 점의 개수:443000000, 원주율의 근사값:3.141803376975169
# 점의 개수:444000000, 원주율의 근사값:3.141806117117117
# 점의 개수:445000000, 원주율의 근사값:3.141800575280899
# 점의 개수:446000000, 원주율의 근사값:3.1417975695067266
# 점의 개수:447000000, 원주율의 근사값:3.141793780760626
# 점의 개수:448000000, 원주율의 근사값:3.141792964285714
# 점의 개수:449000000, 원주율의 근사값:3.1417878040089087
# 점의 개수:450000000, 원주율의 근사값:3.141789022222222
# 점의 개수:451000000, 원주율의 근사값:3.141788842572062
# 점의 개수:452000000, 원주율의 근사값:3.141787814159292
# 점의 개수:453000000, 원주율의 근사값:3.141788008830022
# 점의 개수:454000000, 원주율의 근사값:3.1417849955947137
# 점의 개수:455000000, 원주율의 근사값:3.141785564835165
# 점의 개수:456000000, 원주율의 근사값:3.141782254385965
# 점의 개수:457000000, 원주율의 근사값:3.141778634573304
# 점의 개수:458000000, 원주율의 근사값:3.1417819126637556
# 점의 개수:459000000, 원주율의 근사값:3.141779111111111
# 점의 개수:460000000, 원주율의 근사값:3.1417802695652175
# 점의 개수:461000000, 원주율의 근사값:3.141784468546638
# 점의 개수:462000000, 원주율의 근사값:3.141783567099567
# 점의 개수:463000000, 원주율의 근사값:3.1417847343412526
# 점의 개수:464000000, 원주율의 근사값:3.1417869396551725
# 점의 개수:465000000, 원주율의 근사값:3.1417867956989247
# 점의 개수:466000000, 원주율의 근사값:3.1417842231759656
# 점의 개수:467000000, 원주율의 근사값:3.141778201284797
# 점의 개수:468000000, 원주율의 근사값:3.1417784444444443
# 점의 개수:469000000, 원주율의 근사값:3.141773432835821
# 점의 개수:470000000, 원주율의 근사값:3.141775114893617
# 점의 개수:471000000, 원주율의 근사값:3.1417724501061572
# 점의 개수:472000000, 원주율의 근사값:3.141772491525424
# 점의 개수:473000000, 원주율의 근사값:3.1417711712473575
# 점의 개수:474000000, 원주율의 근사값:3.1417748438818567
# 점의 개수:475000000, 원주율의 근사값:3.1417743242105263
# 점의 개수:476000000, 원주율의 근사값:3.1417741596638655
# 점의 개수:477000000, 원주율의 근사값:3.141776788259958
# 점의 개수:478000000, 원주율의 근사값:3.1417774393305438
# 점의 개수:479000000, 원주율의 근사값:3.141776860125261
# 점의 개수:480000000, 원주율의 근사값:3.141773125
# 점의 개수:481000000, 원주율의 근사값:3.141770162162162
# 점의 개수:482000000, 원주율의 근사값:3.141765369294606
# 점의 개수:483000000, 원주율의 근사값:3.1417657308488613
# 점의 개수:484000000, 원주율의 근사값:3.1417721487603307
# 점의 개수:485000000, 원주율의 근사값:3.1417725773195877
# 점의 개수:486000000, 원주율의 근사값:3.1417696625514404
# 점의 개수:487000000, 원주율의 근사값:3.1417660287474334
# 점의 개수:488000000, 원주율의 근사값:3.1417646147540985
# 점의 개수:489000000, 원주율의 근사값:3.141762036809816
# 점의 개수:490000000, 원주율의 근사값:3.1417612
# 점의 개수:491000000, 원주율의 근사값:3.1417607576374746
# 점의 개수:492000000, 원주율의 근사값:3.141763081300813
# 점의 개수:493000000, 원주율의 근사값:3.141761784989858
# 점의 개수:494000000, 원주율의 근사값:3.14176571659919
# 점의 개수:495000000, 원주율의 근사값:3.1417615757575756
# 점의 개수:496000000, 원주율의 근사값:3.1417653709677418
# 점의 개수:497000000, 원주율의 근사값:3.141760869215292
# 점의 개수:498000000, 원주율의 근사값:3.141762393574297
# 점의 개수:499000000, 원주율의 근사값:3.141760128256513
# 점의 개수:500000000, 원주율의 근사값:3.14175932
# 점의 개수:501000000, 원주율의 근사값:3.1417595449101796
# 점의 개수:502000000, 원주율의 근사값:3.14176
# 점의 개수:503000000, 원주율의 근사값:3.141760874751491
# 점의 개수:504000000, 원주율의 근사값:3.1417643492063494
# 점의 개수:505000000, 원주율의 근사값:3.141762289108911
# 점의 개수:506000000, 원주율의 근사값:3.141760814229249
# 점의 개수:507000000, 원주율의 근사값:3.1417639447731753
# 점의 개수:508000000, 원주율의 근사값:3.141760905511811
# 점의 개수:509000000, 원주율의 근사값:3.141757335952849
# 점의 개수:510000000, 원주율의 근사값:3.141763160784314
# 점의 개수:511000000, 원주율의 근사값:3.1417612524461838
# 점의 개수:512000000, 원주율의 근사값:3.1417661796875
# 점의 개수:513000000, 원주율의 근사값:3.141771547758285
# 점의 개수:514000000, 원주율의 근사값:3.1417671750972764
# 점의 개수:515000000, 원주율의 근사값:3.1417694524271846
# 점의 개수:516000000, 원주율의 근사값:3.1417722403100776
# 점의 개수:517000000, 원주율의 근사값:3.141771837524178
# 점의 개수:518000000, 원주율의 근사값:3.141773583011583
# 점의 개수:519000000, 원주율의 근사값:3.1417734951830445
# 점의 개수:520000000, 원주율의 근사값:3.141774246153846
# 점의 개수:521000000, 원주율의 근사값:3.1417758618042226
# 점의 개수:522000000, 원주율의 근사값:3.1417744750957852
# 점의 개수:523000000, 원주율의 근사값:3.1417755564053538
# 점의 개수:524000000, 원주율의 근사값:3.14177720610687
# 점의 개수:525000000, 원주율의 근사값:3.1417757409523808
# 점의 개수:526000000, 원주율의 근사값:3.1417747452471483
# 점의 개수:527000000, 원주율의 근사값:3.141765760910816
# 점의 개수:528000000, 원주율의 근사값:3.1417595
# 점의 개수:529000000, 원주율의 근사값:3.14175224952741
# 점의 개수:530000000, 원주율의 근사값:3.1417483773584904
# 점의 개수:531000000, 원주율의 근사값:3.1417453860640303
# 점의 개수:532000000, 원주율의 근사값:3.1417476766917294
# 점의 개수:533000000, 원주율의 근사값:3.141742694183865
# 점의 개수:534000000, 원주율의 근사값:3.1417381872659176
# 점의 개수:535000000, 원주율의 근사값:3.1417356112149535
# 점의 개수:536000000, 원주율의 근사값:3.1417356791044777
# 점의 개수:537000000, 원주율의 근사값:3.1417370353817504
# 점의 개수:538000000, 원주율의 근사값:3.141732691449814
# 점의 개수:539000000, 원주율의 근사값:3.141731354359926
# 점의 개수:540000000, 원주율의 근사값:3.1417325185185185
# 점의 개수:541000000, 원주율의 근사값:3.141735844731978
# 점의 개수:542000000, 원주율의 근사값:3.1417363911439113
# 점의 개수:543000000, 원주율의 근사값:3.141734858195212
# 점의 개수:544000000, 원주율의 근사값:3.1417331176470586
# 점의 개수:545000000, 원주율의 근사값:3.14173151559633
# 점의 개수:546000000, 원주율의 근사값:3.141734065934066
# 점의 개수:547000000, 원주율의 근사값:3.1417314442413162
# 점의 개수:548000000, 원주율의 근사값:3.141732832116788
# 점의 개수:549000000, 원주율의 근사값:3.141735067395264
# 점의 개수:550000000, 원주율의 근사값:3.1417320436363636
# 점의 개수:551000000, 원주율의 근사값:3.1417288058076225
# 점의 개수:552000000, 원주율의 근사값:3.141728608695652
# 점의 개수:553000000, 원주율의 근사값:3.1417297504520794
# 점의 개수:554000000, 원주율의 근사값:3.1417230685920576
# 점의 개수:555000000, 원주율의 근사값:3.141722327927928
# 점의 개수:556000000, 원주율의 근사값:3.1417215827338127
# 점의 개수:557000000, 원주율의 근사값:3.1417239281867144
# 점의 개수:558000000, 원주율의 근사값:3.1417273476702507
# 점의 개수:559000000, 원주율의 근사값:3.1417263828264756
# 점의 개수:560000000, 원주율의 근사값:3.1417223714285716
# 점의 개수:561000000, 원주율의 근사값:3.141722916221034
# 점의 개수:562000000, 원주율의 근사값:3.1417184697508898
# 점의 개수:563000000, 원주율의 근사값:3.141715488454707
# 점의 개수:564000000, 원주율의 근사값:3.141720475177305
# 점의 개수:565000000, 원주율의 근사값:3.1417209061946902
# 점의 개수:566000000, 원주율의 근사값:3.141728070671378
# 점의 개수:567000000, 원주율의 근사값:3.1417285291005292
# 점의 개수:568000000, 원주율의 근사값:3.141724753521127
# 점의 개수:569000000, 원주율의 근사값:3.1417288646748682
# 점의 개수:570000000, 원주율의 근사값:3.1417275157894737
# 점의 개수:571000000, 원주율의 근사값:3.1417263467600702
# 점의 개수:572000000, 원주율의 근사값:3.141725643356643
# 점의 개수:573000000, 원주율의 근사값:3.1417279162303666
# 점의 개수:574000000, 원주율의 근사값:3.1417292473867597
# 점의 개수:575000000, 원주율의 근사값:3.141731193043478
# 점의 개수:576000000, 원주율의 근사값:3.141727798611111
# 점의 개수:577000000, 원주율의 근사값:3.1417330537261696
# 점의 개수:578000000, 원주율의 근사값:3.141725813148789
# 점의 개수:579000000, 원주율의 근사값:3.141728877374784
# 점의 개수:580000000, 원주율의 근사값:3.1417275655172414
# 점의 개수:581000000, 원주율의 근사값:3.1417267538726334
# 점의 개수:582000000, 원주율의 근사값:3.141732144329897
# 점의 개수:583000000, 원주율의 근사값:3.141730867924528
# 점의 개수:584000000, 원주율의 근사값:3.1417325205479454
# 점의 개수:585000000, 원주율의 근사값:3.1417262700854702
# 점의 개수:586000000, 원주율의 근사값:3.1417310784982937
# 점의 개수:587000000, 원주율의 근사값:3.1417318432708687
# 점의 개수:588000000, 원주율의 근사값:3.1417336258503403
# 점의 개수:589000000, 원주율의 근사값:3.1417325772495754
# 점의 개수:590000000, 원주율의 근사값:3.141735179661017
# 점의 개수:591000000, 원주율의 근사값:3.14173489678511
# 점의 개수:592000000, 원주율의 근사값:3.1417371216216217
# 점의 개수:593000000, 원주율의 근사값:3.1417340168634063
# 점의 개수:594000000, 원주율의 근사값:3.141729696969697
# 점의 개수:595000000, 원주율의 근사값:3.141733142857143
# 점의 개수:596000000, 원주율의 근사값:3.141733067114094
# 점의 개수:597000000, 원주율의 근사값:3.1417370184254607
# 점의 개수:598000000, 원주율의 근사값:3.1417372709030102
# 점의 개수:599000000, 원주율의 근사값:3.1417377028380633
# 점의 개수:600000000, 원주율의 근사값:3.1417404733333334
# 점의 개수:601000000, 원주율의 근사값:3.1417408519134775
# 점의 개수:602000000, 원주율의 근사값:3.141740272425249
# 점의 개수:603000000, 원주율의 근사값:3.1417396019900496
# 점의 개수:604000000, 원주율의 근사값:3.1417408278145693
# 점의 개수:605000000, 원주율의 근사값:3.141733520661157
# 점의 개수:606000000, 원주율의 근사값:3.1417358349834985
# 점의 개수:607000000, 원주율의 근사값:3.1417373245469524
# 점의 개수:608000000, 원주율의 근사값:3.1417354210526316
# 점의 개수:609000000, 원주율의 근사값:3.141736551724138
# 점의 개수:610000000, 원주율의 근사값:3.1417342032786886
# 점의 개수:611000000, 원주율의 근사값:3.14173643207856
# 점의 개수:612000000, 원주율의 근사값:3.14173968627451
# 점의 개수:613000000, 원주율의 근사값:3.1417445546492657
# 점의 개수:614000000, 원주율의 근사값:3.1417438371335504
# 점의 개수:615000000, 원주율의 근사값:3.1417403772357724
# 점의 개수:616000000, 원주율의 근사값:3.141740383116883
# 점의 개수:617000000, 원주율의 근사값:3.1417426580226904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9632301e5023> in <module>
#       6     for i in range(n):
#       7         x=random.random() # 0~1 사이의 float 값
# ----> 8         y=random.random()
#       9         count+=1
#      10         if x**2+y**2<1: # 단위원 안에 있으면
#
# KeyboardInterrupt:
